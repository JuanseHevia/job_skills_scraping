# %%
# %cd ..
# Out:
# /Users/juansegundohevia/Documents/neni/skill_scraping

# %%
from bs4 import BeautifulSoup
import requests
import re
import json
import os
import pprint

# %% [markdown]
# # Test markitdown

# %%
sample_html = "scraped/sample.html"

# %%
from markitdown import MarkItDown

md = MarkItDown(enable_plugins=False) # Set to True to enable plugins

# %%
result = md.convert(sample_html)
print(result.text_content)
# Out:
# You need to enable JavaScript to run
# this app.
#
# # Gerente Administrativo Financiero SR.
#
# Univista S.A.
#
# [Detalle del empleo](#section-detalle)[La empresa](#section-empresa)[Empleos relacionados](#section-avisos)
#
# ## Publicado ayer
#
# - [## Capital Federal, Buenos Aires, Argentina](/en-buenos-aires/capital-federal/empleos.html)
#
# Buscamos Gerente Administrativo
# Financiero SR.
#
# ### Descripción del puesto
#
# 👉 Buscamos Gerente Administrativo Financiero SR. ℹ La
# búsqueda está orientada a un/a egresado de las carreras
# Contador/a, Administración de Empresas, o afines con perfil
# proactivo, dinámico, flexible con excelentes habilidades
# comunicacionales e interpersonales, trabajo en equipo y
# orientado a resultados. Deberá contar con experiencia previa
# de 5 años en posiciones similares. Deseable con
# especializaciones en el área comercial/ financieras/legales.
# Conocimientos contables para estudio de resultados.
#
# ...

# %% [markdown]
# # Test with URL

# %%
with open("scraped/bumeran_data_20250501_1248.json", "r") as f:
    data = json.load(f)

data[0]
# Out:
# {'url': 'https://bumeran.com.ar/empleos/vendedores-con-experiencia-para-venta-de-planes-de-ahorro-formando-lideres-1116974994.html',
#  'page_number': 1,
# ...

# %%
pprint.pprint(requests.get(data[0]['url']).text)
# Out:
# ('<!DOCTYPE html>\n'
#  '<!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->\n'
#  '<!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->\n'
#  '<!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->\n'
#  '<!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->\n'
#  '<head>\n'
#  '<title>Attention Required! | Cloudflare</title>\n'
#  '<meta charset="UTF-8" />\n'
#  '<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n'
#  '<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n'
#  '<meta name="robots" content="noindex, nofollow" />\n'
#  '<meta name="viewport" content="width=device-width,initial-scale=1" />\n'
#  '<link rel="stylesheet" id="cf_styles-css" '
#  'href="/cdn-cgi/styles/cf.errors.css" />\n'
#  '<!--[if lt IE 9]><link rel="stylesheet" id=\'cf_styles-ie-css\' '
#  'href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->\n'
#  '<style>body{margin:0;padding:0}</style>\n'
# ...
